# %%
import torch
from collections import OrderedDict

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  # Arrange GPU devices starting from 0
os.environ["CUDA_VISIBLE_DEVICES"]= "4"

# %%
bert_path = 'logdir/bert_run/bs=6,qv_link=false,dist=true,orthog=true,orth_init=false,bi_way=true,bi_match=true,dp_link=false,plm=bert/model_checkpoint-00010500'
plm_path = 'logdir/bert_run/bs=6,qv_link=false,dist=true,orthog=true,orth_init=false,bi_way=true,bi_match=true,dp_link=false,plm=bert/model_checkpoint-00085500'

deberta_path = 'logdir/bert_run/bs=6,qv_link=false,dist=true,orthog=false,orth_init=false,bi_way=true,bi_match=true,dp_link=false,plm=deberta/model_checkpoint-00005500'

# %%
# bert_ckpt = torch.load(bert_path)
plm_ckpt = torch.load(plm_path)

# deberta_ckpt = torch.load(deberta_path)
# new_state_dict = OrderedDict()

# for key, value in ckpt['model'].items():
#     if 'bert_model' in key:
#         new_key = key.replace('bert_model', 'plm_model')
#     else:
#         new_key = key

#     new_state_dict[new_key] = value

# ckpt['model'] = new_state_dict

# %%
# bert_model_params = [i for i in bert_ckpt['model'].keys() if 'bert_model' in i]

plm_model_params = [i for i in plm_ckpt['model'].keys() if 'plm_model' in i]

# %%
plm_model_params = [i for i in plm_ckpt['model'].keys() if 'encoder' in i]

# %%
plm_model_params
# Out:
# ['encoder.encs_update.encoder.layers.0.self_attn.linears.0.weight',
#  'encoder.encs_update.encoder.layers.0.self_attn.linears.0.bias',
#  'encoder.encs_update.encoder.layers.0.self_attn.linears.1.weight',
#  'encoder.encs_update.encoder.layers.0.self_attn.linears.1.bias',
#  'encoder.encs_update.encoder.layers.0.self_attn.linears.2.weight',
#  'encoder.encs_update.encoder.layers.0.self_attn.linears.2.bias',
#  'encoder.encs_update.encoder.layers.0.self_attn.linears.3.weight',
#  'encoder.encs_update.encoder.layers.0.self_attn.linears.3.bias',
#  'encoder.encs_update.encoder.layers.0.feed_forward.w_1.weight',
#  'encoder.encs_update.encoder.layers.0.feed_forward.w_1.bias',
#  'encoder.encs_update.encoder.layers.0.feed_forward.w_2.weight',
#  'encoder.encs_update.encoder.layers.0.feed_forward.w_2.bias',
#  'encoder.encs_update.encoder.layers.0.sublayer.0.norm.weight',
#  'encoder.encs_update.encoder.layers.0.sublayer.0.norm.bias',
#  'encoder.encs_update.encoder.layers.0.sublayer.1.norm.weight',
#  'encoder.encs_update.encoder.layers.0.sublayer.1.norm.bias',
#  'encoder.encs_update.encoder.layers.0.relation_k_emb.weight',
#  'encoder.encs_update.encoder.layers.0.relation_v_emb.weight',
#  'encoder.encs_update.encoder.layers.1.self_attn.linears.0.weight',
#  'encoder.encs_update.encoder.layers.1.self_attn.linears.0.bias',
#  'encoder.encs_update.encoder.layers.1.self_attn.linears.1.weight',
#  'encoder.encs_update.encoder.layers.1.self_attn.linears.1.bias',
#  'encoder.encs_update.encoder.layers.1.self_attn.linears.2.weight',
#  'encoder.encs_update.encoder.layers.1.self_attn.linears.2.bias',
#  'encoder.encs_update.encoder.layers.1.self_attn.linears.3.weight',
#  'encoder.encs_update.encoder.layers.1.self_attn.linears.3.bias',
#  'encoder.encs_update.encoder.layers.1.feed_forward.w_1.weight',
#  'encoder.encs_update.encoder.layers.1.feed_forward.w_1.bias',
#  'encoder.encs_update.encoder.layers.1.feed_forward.w_2.weight',
#  'encoder.encs_update.encoder.layers.1.feed_forward.w_2.bias',
#  'encoder.encs_update.encoder.layers.1.sublayer.0.norm.weight',
#  'encoder.encs_update.encoder.layers.1.sublayer.0.norm.bias',
#  'encoder.encs_update.encoder.layers.1.sublayer.1.norm.weight',
#  'encoder.encs_update.encoder.layers.1.sublayer.1.norm.bias',
#  'encoder.encs_update.encoder.layers.1.relation_k_emb.weight',
#  'encoder.encs_update.encoder.layers.1.relation_v_emb.weight',
#  'encoder.encs_update.encoder.layers.2.self_attn.linears.0.weight',
#  'encoder.encs_update.encoder.layers.2.self_attn.linears.0.bias',
#  'encoder.encs_update.encoder.layers.2.self_attn.linears.1.weight',
#  'encoder.encs_update.encoder.layers.2.self_attn.linears.1.bias',
#  'encoder.encs_update.encoder.layers.2.self_attn.linears.2.weight',
#  'encoder.encs_update.encoder.layers.2.self_attn.linears.2.bias',
#  'encoder.encs_update.encoder.layers.2.self_attn.linears.3.weight',
#  'encoder.encs_update.encoder.layers.2.self_attn.linears.3.bias',
#  'encoder.encs_update.encoder.layers.2.feed_forward.w_1.weight',
#  'encoder.encs_update.encoder.layers.2.feed_forward.w_1.bias',
#  'encoder.encs_update.encoder.layers.2.feed_forward.w_2.weight',
#  'encoder.encs_update.encoder.layers.2.feed_forward.w_2.bias',
#  'encoder.encs_update.encoder.layers.2.sublayer.0.norm.weight',
#  'encoder.encs_update.encoder.layers.2.sublayer.0.norm.bias',
#  'encoder.encs_update.encoder.layers.2.sublayer.1.norm.weight',
#  'encoder.encs_update.encoder.layers.2.sublayer.1.norm.bias',
#  'encoder.encs_update.encoder.layers.2.relation_k_emb.weight',
#  'encoder.encs_update.encoder.layers.2.relation_v_emb.weight',
#  'encoder.encs_update.encoder.layers.3.self_attn.linears.0.weight',
#  'encoder.encs_update.encoder.layers.3.self_attn.linears.0.bias',
#  'encoder.encs_update.encoder.layers.3.self_attn.linears.1.weight',
#  'encoder.encs_update.encoder.layers.3.self_attn.linears.1.bias',
#  'encoder.encs_update.encoder.layers.3.self_attn.linears.2.weight',
#  'encoder.encs_update.encoder.layers.3.self_attn.linears.2.bias',
#  'encoder.encs_update.encoder.layers.3.self_attn.linears.3.weight',
#  'encoder.encs_update.encoder.layers.3.self_attn.linears.3.bias',
#  'encoder.encs_update.encoder.layers.3.feed_forward.w_1.weight',
#  'encoder.encs_update.encoder.layers.3.feed_forward.w_1.bias',
#  'encoder.encs_update.encoder.layers.3.feed_forward.w_2.weight',
#  'encoder.encs_update.encoder.layers.3.feed_forward.w_2.bias',
#  'encoder.encs_update.encoder.layers.3.sublayer.0.norm.weight',
#  'encoder.encs_update.encoder.layers.3.sublayer.0.norm.bias',
#  'encoder.encs_update.encoder.layers.3.sublayer.1.norm.weight',
#  'encoder.encs_update.encoder.layers.3.sublayer.1.norm.bias',
#  'encoder.encs_update.encoder.layers.3.relation_k_emb.weight',
#  'encoder.encs_update.encoder.layers.3.relation_v_emb.weight',
#  'encoder.encs_update.encoder.layers.4.self_attn.linears.0.weight',
#  'encoder.encs_update.encoder.layers.4.self_attn.linears.0.bias',
#  'encoder.encs_update.encoder.layers.4.self_attn.linears.1.weight',
#  'encoder.encs_update.encoder.layers.4.self_attn.linears.1.bias',
#  'encoder.encs_update.encoder.layers.4.self_attn.linears.2.weight',
#  'encoder.encs_update.encoder.layers.4.self_attn.linears.2.bias',
#  'encoder.encs_update.encoder.layers.4.self_attn.linears.3.weight',
#  'encoder.encs_update.encoder.layers.4.self_attn.linears.3.bias',
#  'encoder.encs_update.encoder.layers.4.feed_forward.w_1.weight',
#  'encoder.encs_update.encoder.layers.4.feed_forward.w_1.bias',
#  'encoder.encs_update.encoder.layers.4.feed_forward.w_2.weight',
#  'encoder.encs_update.encoder.layers.4.feed_forward.w_2.bias',
#  'encoder.encs_update.encoder.layers.4.sublayer.0.norm.weight',
#  'encoder.encs_update.encoder.layers.4.sublayer.0.norm.bias',
#  'encoder.encs_update.encoder.layers.4.sublayer.1.norm.weight',
#  'encoder.encs_update.encoder.layers.4.sublayer.1.norm.bias',
#  'encoder.encs_update.encoder.layers.4.relation_k_emb.weight',
#  'encoder.encs_update.encoder.layers.4.relation_v_emb.weight',
#  'encoder.encs_update.encoder.layers.5.self_attn.linears.0.weight',
#  'encoder.encs_update.encoder.layers.5.self_attn.linears.0.bias',
#  'encoder.encs_update.encoder.layers.5.self_attn.linears.1.weight',
#  'encoder.encs_update.encoder.layers.5.self_attn.linears.1.bias',
#  'encoder.encs_update.encoder.layers.5.self_attn.linears.2.weight',
#  'encoder.encs_update.encoder.layers.5.self_attn.linears.2.bias',
#  'encoder.encs_update.encoder.layers.5.self_attn.linears.3.weight',
#  'encoder.encs_update.encoder.layers.5.self_attn.linears.3.bias',
#  'encoder.encs_update.encoder.layers.5.feed_forward.w_1.weight',
#  'encoder.encs_update.encoder.layers.5.feed_forward.w_1.bias',
#  'encoder.encs_update.encoder.layers.5.feed_forward.w_2.weight',
#  'encoder.encs_update.encoder.layers.5.feed_forward.w_2.bias',
#  'encoder.encs_update.encoder.layers.5.sublayer.0.norm.weight',
#  'encoder.encs_update.encoder.layers.5.sublayer.0.norm.bias',
#  'encoder.encs_update.encoder.layers.5.sublayer.1.norm.weight',
#  'encoder.encs_update.encoder.layers.5.sublayer.1.norm.bias',
#  'encoder.encs_update.encoder.layers.5.relation_k_emb.weight',
#  'encoder.encs_update.encoder.layers.5.relation_v_emb.weight',
#  'encoder.encs_update.encoder.layers.6.self_attn.linears.0.weight',
#  'encoder.encs_update.encoder.layers.6.self_attn.linears.0.bias',
#  'encoder.encs_update.encoder.layers.6.self_attn.linears.1.weight',
#  'encoder.encs_update.encoder.layers.6.self_attn.linears.1.bias',
#  'encoder.encs_update.encoder.layers.6.self_attn.linears.2.weight',
#  'encoder.encs_update.encoder.layers.6.self_attn.linears.2.bias',
#  'encoder.encs_update.encoder.layers.6.self_attn.linears.3.weight',
#  'encoder.encs_update.encoder.layers.6.self_attn.linears.3.bias',
#  'encoder.encs_update.encoder.layers.6.feed_forward.w_1.weight',
#  'encoder.encs_update.encoder.layers.6.feed_forward.w_1.bias',
#  'encoder.encs_update.encoder.layers.6.feed_forward.w_2.weight',
#  'encoder.encs_update.encoder.layers.6.feed_forward.w_2.bias',
#  'encoder.encs_update.encoder.layers.6.sublayer.0.norm.weight',
#  'encoder.encs_update.encoder.layers.6.sublayer.0.norm.bias',
#  'encoder.encs_update.encoder.layers.6.sublayer.1.norm.weight',
#  'encoder.encs_update.encoder.layers.6.sublayer.1.norm.bias',
#  'encoder.encs_update.encoder.layers.6.relation_k_emb.weight',
#  'encoder.encs_update.encoder.layers.6.relation_v_emb.weight',
#  'encoder.encs_update.encoder.layers.7.self_attn.linears.0.weight',
#  'encoder.encs_update.encoder.layers.7.self_attn.linears.0.bias',
#  'encoder.encs_update.encoder.layers.7.self_attn.linears.1.weight',
#  'encoder.encs_update.encoder.layers.7.self_attn.linears.1.bias',
#  'encoder.encs_update.encoder.layers.7.self_attn.linears.2.weight',
#  'encoder.encs_update.encoder.layers.7.self_attn.linears.2.bias',
#  'encoder.encs_update.encoder.layers.7.self_attn.linears.3.weight',
#  'encoder.encs_update.encoder.layers.7.self_attn.linears.3.bias',
#  'encoder.encs_update.encoder.layers.7.feed_forward.w_1.weight',
#  'encoder.encs_update.encoder.layers.7.feed_forward.w_1.bias',
#  'encoder.encs_update.encoder.layers.7.feed_forward.w_2.weight',
#  'encoder.encs_update.encoder.layers.7.feed_forward.w_2.bias',
#  'encoder.encs_update.encoder.layers.7.sublayer.0.norm.weight',
#  'encoder.encs_update.encoder.layers.7.sublayer.0.norm.bias',
#  'encoder.encs_update.encoder.layers.7.sublayer.1.norm.weight',
#  'encoder.encs_update.encoder.layers.7.sublayer.1.norm.bias',
#  'encoder.encs_update.encoder.layers.7.relation_k_emb.weight',
#  'encoder.encs_update.encoder.layers.7.relation_v_emb.weight',
#  'encoder.encs_update.encoder.norm.weight',
#  'encoder.encs_update.encoder.norm.bias',
#  'encoder.encs_update.align_attn.linears.0.weight',
#  'encoder.encs_update.align_attn.linears.0.bias',
#  'encoder.encs_update.align_attn.linears.1.weight',
#  'encoder.encs_update.align_attn.linears.1.bias',
#  'encoder.encs_update.align_attn.linears.2.weight',
#  'encoder.encs_update.align_attn.linears.2.bias',
#  'encoder.encs_update.align_attn.relation_k_emb.weight',
#  'encoder.encs_update.align_attn.relation_v_emb.weight',
#  'encoder.plm_model.embeddings.position_ids',
#  'encoder.plm_model.embeddings.word_embeddings.weight',
#  'encoder.plm_model.embeddings.position_embeddings.weight',
#  'encoder.plm_model.embeddings.token_type_embeddings.weight',
#  'encoder.plm_model.embeddings.LayerNorm.weight',
#  'encoder.plm_model.embeddings.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.0.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.0.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.0.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.0.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.0.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.0.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.0.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.0.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.0.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.0.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.0.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.0.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.0.output.dense.weight',
#  'encoder.plm_model.encoder.layer.0.output.dense.bias',
#  'encoder.plm_model.encoder.layer.0.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.0.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.1.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.1.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.1.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.1.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.1.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.1.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.1.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.1.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.1.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.1.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.1.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.1.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.1.output.dense.weight',
#  'encoder.plm_model.encoder.layer.1.output.dense.bias',
#  'encoder.plm_model.encoder.layer.1.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.1.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.2.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.2.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.2.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.2.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.2.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.2.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.2.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.2.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.2.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.2.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.2.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.2.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.2.output.dense.weight',
#  'encoder.plm_model.encoder.layer.2.output.dense.bias',
#  'encoder.plm_model.encoder.layer.2.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.2.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.3.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.3.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.3.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.3.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.3.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.3.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.3.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.3.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.3.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.3.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.3.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.3.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.3.output.dense.weight',
#  'encoder.plm_model.encoder.layer.3.output.dense.bias',
#  'encoder.plm_model.encoder.layer.3.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.3.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.4.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.4.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.4.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.4.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.4.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.4.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.4.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.4.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.4.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.4.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.4.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.4.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.4.output.dense.weight',
#  'encoder.plm_model.encoder.layer.4.output.dense.bias',
#  'encoder.plm_model.encoder.layer.4.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.4.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.5.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.5.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.5.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.5.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.5.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.5.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.5.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.5.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.5.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.5.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.5.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.5.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.5.output.dense.weight',
#  'encoder.plm_model.encoder.layer.5.output.dense.bias',
#  'encoder.plm_model.encoder.layer.5.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.5.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.6.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.6.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.6.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.6.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.6.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.6.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.6.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.6.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.6.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.6.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.6.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.6.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.6.output.dense.weight',
#  'encoder.plm_model.encoder.layer.6.output.dense.bias',
#  'encoder.plm_model.encoder.layer.6.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.6.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.7.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.7.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.7.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.7.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.7.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.7.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.7.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.7.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.7.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.7.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.7.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.7.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.7.output.dense.weight',
#  'encoder.plm_model.encoder.layer.7.output.dense.bias',
#  'encoder.plm_model.encoder.layer.7.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.7.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.8.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.8.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.8.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.8.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.8.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.8.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.8.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.8.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.8.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.8.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.8.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.8.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.8.output.dense.weight',
#  'encoder.plm_model.encoder.layer.8.output.dense.bias',
#  'encoder.plm_model.encoder.layer.8.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.8.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.9.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.9.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.9.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.9.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.9.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.9.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.9.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.9.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.9.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.9.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.9.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.9.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.9.output.dense.weight',
#  'encoder.plm_model.encoder.layer.9.output.dense.bias',
#  'encoder.plm_model.encoder.layer.9.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.9.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.10.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.10.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.10.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.10.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.10.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.10.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.10.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.10.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.10.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.10.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.10.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.10.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.10.output.dense.weight',
#  'encoder.plm_model.encoder.layer.10.output.dense.bias',
#  'encoder.plm_model.encoder.layer.10.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.10.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.11.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.11.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.11.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.11.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.11.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.11.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.11.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.11.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.11.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.11.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.11.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.11.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.11.output.dense.weight',
#  'encoder.plm_model.encoder.layer.11.output.dense.bias',
#  'encoder.plm_model.encoder.layer.11.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.11.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.12.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.12.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.12.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.12.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.12.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.12.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.12.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.12.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.12.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.12.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.12.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.12.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.12.output.dense.weight',
#  'encoder.plm_model.encoder.layer.12.output.dense.bias',
#  'encoder.plm_model.encoder.layer.12.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.12.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.13.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.13.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.13.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.13.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.13.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.13.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.13.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.13.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.13.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.13.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.13.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.13.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.13.output.dense.weight',
#  'encoder.plm_model.encoder.layer.13.output.dense.bias',
#  'encoder.plm_model.encoder.layer.13.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.13.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.14.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.14.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.14.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.14.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.14.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.14.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.14.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.14.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.14.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.14.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.14.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.14.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.14.output.dense.weight',
#  'encoder.plm_model.encoder.layer.14.output.dense.bias',
#  'encoder.plm_model.encoder.layer.14.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.14.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.15.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.15.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.15.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.15.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.15.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.15.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.15.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.15.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.15.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.15.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.15.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.15.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.15.output.dense.weight',
#  'encoder.plm_model.encoder.layer.15.output.dense.bias',
#  'encoder.plm_model.encoder.layer.15.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.15.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.16.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.16.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.16.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.16.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.16.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.16.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.16.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.16.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.16.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.16.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.16.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.16.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.16.output.dense.weight',
#  'encoder.plm_model.encoder.layer.16.output.dense.bias',
#  'encoder.plm_model.encoder.layer.16.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.16.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.17.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.17.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.17.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.17.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.17.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.17.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.17.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.17.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.17.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.17.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.17.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.17.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.17.output.dense.weight',
#  'encoder.plm_model.encoder.layer.17.output.dense.bias',
#  'encoder.plm_model.encoder.layer.17.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.17.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.18.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.18.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.18.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.18.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.18.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.18.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.18.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.18.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.18.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.18.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.18.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.18.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.18.output.dense.weight',
#  'encoder.plm_model.encoder.layer.18.output.dense.bias',
#  'encoder.plm_model.encoder.layer.18.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.18.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.19.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.19.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.19.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.19.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.19.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.19.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.19.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.19.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.19.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.19.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.19.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.19.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.19.output.dense.weight',
#  'encoder.plm_model.encoder.layer.19.output.dense.bias',
#  'encoder.plm_model.encoder.layer.19.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.19.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.20.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.20.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.20.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.20.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.20.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.20.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.20.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.20.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.20.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.20.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.20.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.20.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.20.output.dense.weight',
#  'encoder.plm_model.encoder.layer.20.output.dense.bias',
#  'encoder.plm_model.encoder.layer.20.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.20.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.21.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.21.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.21.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.21.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.21.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.21.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.21.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.21.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.21.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.21.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.21.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.21.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.21.output.dense.weight',
#  'encoder.plm_model.encoder.layer.21.output.dense.bias',
#  'encoder.plm_model.encoder.layer.21.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.21.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.22.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.22.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.22.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.22.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.22.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.22.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.22.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.22.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.22.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.22.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.22.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.22.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.22.output.dense.weight',
#  'encoder.plm_model.encoder.layer.22.output.dense.bias',
#  'encoder.plm_model.encoder.layer.22.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.22.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.23.attention.self.query.weight',
#  'encoder.plm_model.encoder.layer.23.attention.self.query.bias',
#  'encoder.plm_model.encoder.layer.23.attention.self.key.weight',
#  'encoder.plm_model.encoder.layer.23.attention.self.key.bias',
#  'encoder.plm_model.encoder.layer.23.attention.self.value.weight',
#  'encoder.plm_model.encoder.layer.23.attention.self.value.bias',
#  'encoder.plm_model.encoder.layer.23.attention.output.dense.weight',
#  'encoder.plm_model.encoder.layer.23.attention.output.dense.bias',
#  'encoder.plm_model.encoder.layer.23.attention.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.23.attention.output.LayerNorm.bias',
#  'encoder.plm_model.encoder.layer.23.intermediate.dense.weight',
#  'encoder.plm_model.encoder.layer.23.intermediate.dense.bias',
#  'encoder.plm_model.encoder.layer.23.output.dense.weight',
#  'encoder.plm_model.encoder.layer.23.output.dense.bias',
#  'encoder.plm_model.encoder.layer.23.output.LayerNorm.weight',
#  'encoder.plm_model.encoder.layer.23.output.LayerNorm.bias',
#  'encoder.plm_model.pooler.dense.weight',
#  'encoder.plm_model.pooler.dense.bias']
