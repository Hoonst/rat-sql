# %% [markdown]
# # Dependency Parsing

# %%
from notebooks.utils import *
import itertools

# %%
train_data = read_jsonl('data/spider/nl2code,output_from=true,fs=2,emb=bert,cvlink/enc/train.jsonl')

# %%
train_data_questions = [i['raw_question'] for i in train_data]
train_data_qj = [j['question'] for j in train_data]

# %%
raw_question = train_data[10]['raw_question']
question = train_data[10]['question']
question_join = ' '.join(question)

print(f'raw_question: {raw_question}')
print(f'question: {question}')
print(f'question_join: {question_join}')
# Out:
# raw_question: How many acting statuses are there?
# question: ['how', 'many', 'acting', 'status', '##es', 'are', 'there', '?']
# question_join: how many acting status ##es are there ?

# %%
import stanza, spacy

nlp_stanza = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma,depparse')
# doc_stanza = nlp_stanza(question_join)

nlp_spacy = spacy.load("en_core_web_sm")

dp_whole_stanza = []
dp_whole_spacy = []


for qj in train_data_qj:
    
    dp_linkage_stanza, dp_linkage_spacy = {}, {}
    doc_stanza = nlp_stanza(' '.join(qj))
    doc_spacy = nlp_spacy(' '.join(qj))

    words_stanza = doc_stanza.sentences[0].words

    for i in range(len(words_stanza)):
        words_stanza[i].id -= 1 
        words_stanza[i].head -= 1

    words_spacy  = []

    for idx, token in enumerate(doc_spacy):

        words_spacy.append({"id": idx,
                            "text": token.text,
                            "dep": token.dep_,
                            "head": token.head.i})

    # print(f'Original Sentence: {qj}')
    # print(f'')

    for i, j in itertools.product(range(len(words_spacy)), repeat=2):
        if i == j:
            continue
        
        # if head's index is 0 > ROOT Node
        elif words_spacy[i]['head'] == words_spacy[i]['id']:
            continue

        elif words_spacy[i]['head'] == j:
            dp_linkage_spacy[f"{j},{i}"] = 'F'
            dp_linkage_spacy[f"{i},{j}"] = 'B'

    dp_link_spacy = {"dp_link": dp_linkage_spacy}

    for i, j in itertools.product(range(len(words_stanza)), repeat=2):
        if i == j:
            continue
        
        # if head's index is 0 > ROOT Node
        elif words_stanza[i].head == -1:
            continue

        elif words_stanza[i].head == j:
            dp_linkage_stanza[f"{j},{i}"] = 'F'
            dp_linkage_stanza[f"{i},{j}"] = 'B'


    dp_link_stanza = {"dp_link": dp_linkage_stanza}

    print(f'words_spacy:')
    for w in words_spacy:
        print(w)
    print('-'*30)
    print(f'dp_link_spacy: {dp_link_spacy}')
    print('='*30)
    print(f'words_stanza: {words_stanza}')
    print('-'*30)
    print(f'dp_link_stanza: {dp_link_stanza}')
    print('='*30)

    dp_whole_spacy.append(dp_link_spacy)
    dp_whole_stanza.append(dp_link_stanza)

    # print(*[f'id: {word.id}\tword: {word.text}\thead id: {word.head}\thead: {sent.words[word.head-1].text if word.head > 0 else "root"}\tdeprel: {word.deprel}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# 2022-10-05 01:56:35 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2022-10-05 01:56:35 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# | depparse  | combined |
# ========================
#
# 2022-10-05 01:56:35 INFO: Use device: gpu
# 2022-10-05 01:56:35 INFO: Loading: tokenize
# 2022-10-05 01:56:35 INFO: Loading: pos
# 2022-10-05 01:56:36 INFO: Loading: lemma
# 2022-10-05 01:56:36 INFO: Loading: depparse
# 2022-10-05 01:56:36 INFO: Done loading processors!
# words_spacy:
# {'id': 0, 'text': 'how', 'dep': 'advmod', 'head': 1}
# {'id': 1, 'text': 'many', 'dep': 'amod', 'head': 2}
# {'id': 2, 'text': 'heads', 'dep': 'nsubj', 'head': 6}
# {'id': 3, 'text': 'of', 'dep': 'prep', 'head': 2}
# {'id': 4, 'text': 'the', 'dep': 'det', 'head': 5}
# {'id': 5, 'text': 'departments', 'dep': 'pobj', 'head': 3}
# {'id': 6, 'text': 'are', 'dep': 'ROOT', 'head': 6}
# {'id': 7, 'text': 'older', 'dep': 'acomp', 'head': 6}
# {'id': 8, 'text': 'than', 'dep': 'prep', 'head': 7}
# {'id': 9, 'text': '56', 'dep': 'pobj', 'head': 8}
# {'id': 10, 'text': '?', 'dep': 'punct', 'head': 6}
# ------------------------------
# dp_link_spacy: {'dp_link': {'1,0': 'F', '0,1': 'B', '2,1': 'F', '1,2': 'B', '6,2': 'F', '2,6': 'B', '2,3': 'F', '3,2': 'B', '5,4': 'F', '4,5': 'B', '3,5': 'F', '5,3': 'B', '6,7': 'F', '7,6': 'B', '7,8': 'F', '8,7': 'B', '8,9': 'F', '9,8': 'B', '6,10': 'F', '10,6': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "how",
#   "lemma": "how",
#   "upos": "ADV",
#   "xpos": "WRB",
#   "feats": "PronType=Int",
#   "head": 1,
#   "deprel": "advmod",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "id": 1,
#   "text": "many",
#   "lemma": "many",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 2,
#   "deprel": "amod",
#   "start_char": 4,
#   "end_char": 8
# }, {
#   "id": 2,
#   "text": "heads",
#   "lemma": "head",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 7,
#   "deprel": "nsubj",
#   "start_char": 9,
#   "end_char": 14
# }, {
#   "id": 3,
#   "text": "of",
#   "lemma": "of",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 5,
#   "deprel": "case",
#   "start_char": 15,
#   "end_char": 17
# }, {
#   "id": 4,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 5,
#   "deprel": "det",
#   "start_char": 18,
#   "end_char": 21
# }, {
#   "id": 5,
#   "text": "departments",
#   "lemma": "department",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 2,
#   "deprel": "nmod",
#   "start_char": 22,
#   "end_char": 33
# }, {
#   "id": 6,
#   "text": "are",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBP",
#   "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#   "head": 7,
#   "deprel": "cop",
#   "start_char": 34,
#   "end_char": 37
# }, {
#   "id": 7,
#   "text": "older",
#   "lemma": "old",
#   "upos": "ADJ",
#   "xpos": "JJR",
#   "feats": "Degree=Cmp",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 38,
#   "end_char": 43
# }, {
#   "id": 8,
#   "text": "than",
#   "lemma": "than",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 9,
#   "deprel": "case",
#   "start_char": 44,
#   "end_char": 48
# }, {
#   "id": 9,
#   "text": "56",
#   "lemma": "56",
#   "upos": "NUM",
#   "xpos": "CD",
#   "feats": "NumType=Card",
#   "head": 7,
#   "deprel": "obl",
#   "start_char": 49,
#   "end_char": 51
# }, {
#   "id": 10,
#   "text": "?",
#   "lemma": "?",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 7,
#   "deprel": "punct",
#   "start_char": 52,
#   "end_char": 53
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'1,0': 'F', '0,1': 'B', '2,1': 'F', '1,2': 'B', '7,2': 'F', '2,7': 'B', '5,3': 'F', '3,5': 'B', '5,4': 'F', '4,5': 'B', '2,5': 'F', '5,2': 'B', '7,6': 'F', '6,7': 'B', '9,8': 'F', '8,9': 'B', '7,9': 'F', '9,7': 'B', '7,10': 'F', '10,7': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'list', 'dep': 'ROOT', 'head': 0}
# {'id': 1, 'text': 'the', 'dep': 'det', 'head': 2}
# {'id': 2, 'text': 'name', 'dep': 'dobj', 'head': 0}
# {'id': 3, 'text': ',', 'dep': 'punct', 'head': 2}
# {'id': 4, 'text': 'born', 'dep': 'amod', 'head': 5}
# {'id': 5, 'text': 'state', 'dep': 'conj', 'head': 2}
# {'id': 6, 'text': 'and', 'dep': 'cc', 'head': 5}
# {'id': 7, 'text': 'age', 'dep': 'conj', 'head': 5}
# {'id': 8, 'text': 'of', 'dep': 'prep', 'head': 5}
# {'id': 9, 'text': 'the', 'dep': 'det', 'head': 10}
# {'id': 10, 'text': 'heads', 'dep': 'pobj', 'head': 8}
# {'id': 11, 'text': 'of', 'dep': 'prep', 'head': 10}
# {'id': 12, 'text': 'departments', 'dep': 'pobj', 'head': 11}
# {'id': 13, 'text': 'ordered', 'dep': 'acl', 'head': 12}
# {'id': 14, 'text': 'by', 'dep': 'agent', 'head': 13}
# {'id': 15, 'text': 'age', 'dep': 'pobj', 'head': 14}
# {'id': 16, 'text': '.', 'dep': 'punct', 'head': 0}
# ------------------------------
# dp_link_spacy: {'dp_link': {'2,1': 'F', '1,2': 'B', '0,2': 'F', '2,0': 'B', '2,3': 'F', '3,2': 'B', '5,4': 'F', '4,5': 'B', '2,5': 'F', '5,2': 'B', '5,6': 'F', '6,5': 'B', '5,7': 'F', '7,5': 'B', '5,8': 'F', '8,5': 'B', '10,9': 'F', '9,10': 'B', '8,10': 'F', '10,8': 'B', '10,11': 'F', '11,10': 'B', '11,12': 'F', '12,11': 'B', '12,13': 'F', '13,12': 'B', '13,14': 'F', '14,13': 'B', '14,15': 'F', '15,14': 'B', '0,16': 'F', '16,0': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "list",
#   "lemma": "list",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "Mood=Imp|VerbForm=Fin",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 0,
#   "end_char": 4
# }, {
#   "id": 1,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 2,
#   "deprel": "det",
#   "start_char": 5,
#   "end_char": 8
# }, {
#   "id": 2,
#   "text": "name",
#   "lemma": "name",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 0,
#   "deprel": "obj",
#   "start_char": 9,
#   "end_char": 13
# }, {
#   "id": 3,
#   "text": ",",
#   "lemma": ",",
#   "upos": "PUNCT",
#   "xpos": ",",
#   "head": 5,
#   "deprel": "punct",
#   "start_char": 14,
#   "end_char": 15
# }, {
#   "id": 4,
#   "text": "born",
#   "lemma": "bear",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 5,
#   "deprel": "amod",
#   "start_char": 16,
#   "end_char": 20
# }, {
#   "id": 5,
#   "text": "state",
#   "lemma": "state",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 2,
#   "deprel": "conj",
#   "start_char": 21,
#   "end_char": 26
# }, {
#   "id": 6,
#   "text": "and",
#   "lemma": "and",
#   "upos": "CCONJ",
#   "xpos": "CC",
#   "head": 7,
#   "deprel": "cc",
#   "start_char": 27,
#   "end_char": 30
# }, {
#   "id": 7,
#   "text": "age",
#   "lemma": "age",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 2,
#   "deprel": "conj",
#   "start_char": 31,
#   "end_char": 34
# }, {
#   "id": 8,
#   "text": "of",
#   "lemma": "of",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 10,
#   "deprel": "case",
#   "start_char": 35,
#   "end_char": 37
# }, {
#   "id": 9,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 10,
#   "deprel": "det",
#   "start_char": 38,
#   "end_char": 41
# }, {
#   "id": 10,
#   "text": "heads",
#   "lemma": "head",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 7,
#   "deprel": "nmod",
#   "start_char": 42,
#   "end_char": 47
# }, {
#   "id": 11,
#   "text": "of",
#   "lemma": "of",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 12,
#   "deprel": "case",
#   "start_char": 48,
#   "end_char": 50
# }, {
#   "id": 12,
#   "text": "departments",
#   "lemma": "department",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 10,
#   "deprel": "nmod",
#   "start_char": 51,
#   "end_char": 62
# }, {
#   "id": 13,
#   "text": "ordered",
#   "lemma": "order",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 10,
#   "deprel": "acl",
#   "start_char": 63,
#   "end_char": 70
# }, {
#   "id": 14,
#   "text": "by",
#   "lemma": "by",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 15,
#   "deprel": "case",
#   "start_char": 71,
#   "end_char": 73
# }, {
#   "id": 15,
#   "text": "age",
#   "lemma": "age",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 13,
#   "deprel": "obl",
#   "start_char": 74,
#   "end_char": 77
# }, {
#   "id": 16,
#   "text": ".",
#   "lemma": ".",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 0,
#   "deprel": "punct",
#   "start_char": 78,
#   "end_char": 79
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'2,1': 'F', '1,2': 'B', '0,2': 'F', '2,0': 'B', '5,3': 'F', '3,5': 'B', '5,4': 'F', '4,5': 'B', '2,5': 'F', '5,2': 'B', '7,6': 'F', '6,7': 'B', '2,7': 'F', '7,2': 'B', '10,8': 'F', '8,10': 'B', '10,9': 'F', '9,10': 'B', '7,10': 'F', '10,7': 'B', '12,11': 'F', '11,12': 'B', '10,12': 'F', '12,10': 'B', '10,13': 'F', '13,10': 'B', '15,14': 'F', '14,15': 'B', '13,15': 'F', '15,13': 'B', '0,16': 'F', '16,0': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'list', 'dep': 'ROOT', 'head': 0}
# {'id': 1, 'text': 'the', 'dep': 'det', 'head': 3}
# {'id': 2, 'text': 'creation', 'dep': 'compound', 'head': 3}
# {'id': 3, 'text': 'year', 'dep': 'dobj', 'head': 0}
# {'id': 4, 'text': ',', 'dep': 'punct', 'head': 3}
# {'id': 5, 'text': 'name', 'dep': 'conj', 'head': 3}
# {'id': 6, 'text': 'and', 'dep': 'cc', 'head': 5}
# {'id': 7, 'text': 'budget', 'dep': 'conj', 'head': 5}
# {'id': 8, 'text': 'of', 'dep': 'prep', 'head': 5}
# {'id': 9, 'text': 'each', 'dep': 'det', 'head': 10}
# {'id': 10, 'text': 'department', 'dep': 'pobj', 'head': 8}
# {'id': 11, 'text': '.', 'dep': 'punct', 'head': 0}
# ------------------------------
# dp_link_spacy: {'dp_link': {'3,1': 'F', '1,3': 'B', '3,2': 'F', '2,3': 'B', '0,3': 'F', '3,0': 'B', '3,4': 'F', '4,3': 'B', '3,5': 'F', '5,3': 'B', '5,6': 'F', '6,5': 'B', '5,7': 'F', '7,5': 'B', '5,8': 'F', '8,5': 'B', '10,9': 'F', '9,10': 'B', '8,10': 'F', '10,8': 'B', '0,11': 'F', '11,0': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "list",
#   "lemma": "list",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "Mood=Imp|VerbForm=Fin",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 0,
#   "end_char": 4
# }, {
#   "id": 1,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 3,
#   "deprel": "det",
#   "start_char": 5,
#   "end_char": 8
# }, {
#   "id": 2,
#   "text": "creation",
#   "lemma": "creation",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 3,
#   "deprel": "compound",
#   "start_char": 9,
#   "end_char": 17
# }, {
#   "id": 3,
#   "text": "year",
#   "lemma": "year",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 0,
#   "deprel": "obj",
#   "start_char": 18,
#   "end_char": 22
# }, {
#   "id": 4,
#   "text": ",",
#   "lemma": ",",
#   "upos": "PUNCT",
#   "xpos": ",",
#   "head": 5,
#   "deprel": "punct",
#   "start_char": 23,
#   "end_char": 24
# }, {
#   "id": 5,
#   "text": "name",
#   "lemma": "name",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 3,
#   "deprel": "conj",
#   "start_char": 25,
#   "end_char": 29
# }, {
#   "id": 6,
#   "text": "and",
#   "lemma": "and",
#   "upos": "CCONJ",
#   "xpos": "CC",
#   "head": 7,
#   "deprel": "cc",
#   "start_char": 30,
#   "end_char": 33
# }, {
#   "id": 7,
#   "text": "budget",
#   "lemma": "budget",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 3,
#   "deprel": "conj",
#   "start_char": 34,
#   "end_char": 40
# }, {
#   "id": 8,
#   "text": "of",
#   "lemma": "of",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 10,
#   "deprel": "case",
#   "start_char": 41,
#   "end_char": 43
# }, {
#   "id": 9,
#   "text": "each",
#   "lemma": "each",
#   "upos": "DET",
#   "xpos": "DT",
#   "head": 10,
#   "deprel": "det",
#   "start_char": 44,
#   "end_char": 48
# }, {
#   "id": 10,
#   "text": "department",
#   "lemma": "department",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 3,
#   "deprel": "nmod",
#   "start_char": 49,
#   "end_char": 59
# }, {
#   "id": 11,
#   "text": ".",
#   "lemma": ".",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 0,
#   "deprel": "punct",
#   "start_char": 60,
#   "end_char": 61
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'3,1': 'F', '1,3': 'B', '3,2': 'F', '2,3': 'B', '0,3': 'F', '3,0': 'B', '5,4': 'F', '4,5': 'B', '3,5': 'F', '5,3': 'B', '7,6': 'F', '6,7': 'B', '3,7': 'F', '7,3': 'B', '10,8': 'F', '8,10': 'B', '10,9': 'F', '9,10': 'B', '3,10': 'F', '10,3': 'B', '0,11': 'F', '11,0': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'what', 'dep': 'attr', 'head': 1}
# {'id': 1, 'text': 'are', 'dep': 'ROOT', 'head': 1}
# {'id': 2, 'text': 'the', 'dep': 'det', 'head': 6}
# {'id': 3, 'text': 'maximum', 'dep': 'amod', 'head': 6}
# {'id': 4, 'text': 'and', 'dep': 'cc', 'head': 3}
# {'id': 5, 'text': 'minimum', 'dep': 'conj', 'head': 3}
# {'id': 6, 'text': 'budget', 'dep': 'nsubj', 'head': 1}
# {'id': 7, 'text': 'of', 'dep': 'prep', 'head': 6}
# {'id': 8, 'text': 'the', 'dep': 'det', 'head': 9}
# {'id': 9, 'text': 'departments', 'dep': 'pobj', 'head': 7}
# {'id': 10, 'text': '?', 'dep': 'punct', 'head': 1}
# ------------------------------
# dp_link_spacy: {'dp_link': {'1,0': 'F', '0,1': 'B', '6,2': 'F', '2,6': 'B', '6,3': 'F', '3,6': 'B', '3,4': 'F', '4,3': 'B', '3,5': 'F', '5,3': 'B', '1,6': 'F', '6,1': 'B', '6,7': 'F', '7,6': 'B', '9,8': 'F', '8,9': 'B', '7,9': 'F', '9,7': 'B', '1,10': 'F', '10,1': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "what",
#   "lemma": "what",
#   "upos": "PRON",
#   "xpos": "WP",
#   "feats": "PronType=Int",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 0,
#   "end_char": 4
# }, {
#   "id": 1,
#   "text": "are",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBP",
#   "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#   "head": 0,
#   "deprel": "cop",
#   "start_char": 5,
#   "end_char": 8
# }, {
#   "id": 2,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 6,
#   "deprel": "det",
#   "start_char": 9,
#   "end_char": 12
# }, {
#   "id": 3,
#   "text": "maximum",
#   "lemma": "maximum",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 6,
#   "deprel": "amod",
#   "start_char": 13,
#   "end_char": 20
# }, {
#   "id": 4,
#   "text": "and",
#   "lemma": "and",
#   "upos": "CCONJ",
#   "xpos": "CC",
#   "head": 5,
#   "deprel": "cc",
#   "start_char": 21,
#   "end_char": 24
# }, {
#   "id": 5,
#   "text": "minimum",
#   "lemma": "minimum",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 3,
#   "deprel": "conj",
#   "start_char": 25,
#   "end_char": 32
# }, {
#   "id": 6,
#   "text": "budget",
#   "lemma": "budget",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 0,
#   "deprel": "nsubj",
#   "start_char": 33,
#   "end_char": 39
# }, {
#   "id": 7,
#   "text": "of",
#   "lemma": "of",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 9,
#   "deprel": "case",
#   "start_char": 40,
#   "end_char": 42
# }, {
#   "id": 8,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 9,
#   "deprel": "det",
#   "start_char": 43,
#   "end_char": 46
# }, {
#   "id": 9,
#   "text": "departments",
#   "lemma": "department",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 6,
#   "deprel": "nmod",
#   "start_char": 47,
#   "end_char": 58
# }, {
#   "id": 10,
#   "text": "?",
#   "lemma": "?",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 0,
#   "deprel": "punct",
#   "start_char": 59,
#   "end_char": 60
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'0,1': 'F', '1,0': 'B', '6,2': 'F', '2,6': 'B', '6,3': 'F', '3,6': 'B', '5,4': 'F', '4,5': 'B', '3,5': 'F', '5,3': 'B', '0,6': 'F', '6,0': 'B', '9,7': 'F', '7,9': 'B', '9,8': 'F', '8,9': 'B', '6,9': 'F', '9,6': 'B', '0,10': 'F', '10,0': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'what', 'dep': 'attr', 'head': 1}
# {'id': 1, 'text': 'is', 'dep': 'ROOT', 'head': 1}
# {'id': 2, 'text': 'the', 'dep': 'det', 'head': 4}
# {'id': 3, 'text': 'average', 'dep': 'amod', 'head': 4}
# {'id': 4, 'text': 'number', 'dep': 'nsubj', 'head': 1}
# {'id': 5, 'text': 'of', 'dep': 'prep', 'head': 4}
# {'id': 6, 'text': 'employees', 'dep': 'pobj', 'head': 5}
# {'id': 7, 'text': 'of', 'dep': 'prep', 'head': 6}
# {'id': 8, 'text': 'the', 'dep': 'det', 'head': 9}
# {'id': 9, 'text': 'departments', 'dep': 'pobj', 'head': 7}
# {'id': 10, 'text': 'whose', 'dep': 'poss', 'head': 11}
# {'id': 11, 'text': 'rank', 'dep': 'nsubj', 'head': 12}
# {'id': 12, 'text': 'is', 'dep': 'relcl', 'head': 9}
# {'id': 13, 'text': 'between', 'dep': 'quantmod', 'head': 14}
# {'id': 14, 'text': '10', 'dep': 'attr', 'head': 12}
# {'id': 15, 'text': 'and', 'dep': 'cc', 'head': 14}
# {'id': 16, 'text': '15', 'dep': 'conj', 'head': 14}
# {'id': 17, 'text': '?', 'dep': 'punct', 'head': 1}
# ------------------------------
# dp_link_spacy: {'dp_link': {'1,0': 'F', '0,1': 'B', '4,2': 'F', '2,4': 'B', '4,3': 'F', '3,4': 'B', '1,4': 'F', '4,1': 'B', '4,5': 'F', '5,4': 'B', '5,6': 'F', '6,5': 'B', '6,7': 'F', '7,6': 'B', '9,8': 'F', '8,9': 'B', '7,9': 'F', '9,7': 'B', '11,10': 'F', '10,11': 'B', '12,11': 'F', '11,12': 'B', '9,12': 'F', '12,9': 'B', '14,13': 'F', '13,14': 'B', '12,14': 'F', '14,12': 'B', '14,15': 'F', '15,14': 'B', '14,16': 'F', '16,14': 'B', '1,17': 'F', '17,1': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "what",
#   "lemma": "what",
#   "upos": "PRON",
#   "xpos": "WP",
#   "feats": "PronType=Int",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 0,
#   "end_char": 4
# }, {
#   "id": 1,
#   "text": "is",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBZ",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#   "head": 0,
#   "deprel": "cop",
#   "start_char": 5,
#   "end_char": 7
# }, {
#   "id": 2,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 4,
#   "deprel": "det",
#   "start_char": 8,
#   "end_char": 11
# }, {
#   "id": 3,
#   "text": "average",
#   "lemma": "average",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 4,
#   "deprel": "amod",
#   "start_char": 12,
#   "end_char": 19
# }, {
#   "id": 4,
#   "text": "number",
#   "lemma": "number",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 0,
#   "deprel": "nsubj",
#   "start_char": 20,
#   "end_char": 26
# }, {
#   "id": 5,
#   "text": "of",
#   "lemma": "of",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 6,
#   "deprel": "case",
#   "start_char": 27,
#   "end_char": 29
# }, {
#   "id": 6,
#   "text": "employees",
#   "lemma": "employee",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 4,
#   "deprel": "nmod",
#   "start_char": 30,
#   "end_char": 39
# }, {
#   "id": 7,
#   "text": "of",
#   "lemma": "of",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 9,
#   "deprel": "case",
#   "start_char": 40,
#   "end_char": 42
# }, {
#   "id": 8,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 9,
#   "deprel": "det",
#   "start_char": 43,
#   "end_char": 46
# }, {
#   "id": 9,
#   "text": "departments",
#   "lemma": "department",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 6,
#   "deprel": "nmod",
#   "start_char": 47,
#   "end_char": 58
# }, {
#   "id": 10,
#   "text": "whose",
#   "lemma": "whose",
#   "upos": "PRON",
#   "xpos": "WP$",
#   "feats": "Poss=Yes|PronType=Int",
#   "head": 11,
#   "deprel": "nmod:poss",
#   "start_char": 59,
#   "end_char": 64
# }, {
#   "id": 11,
#   "text": "rank",
#   "lemma": "rank",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 14,
#   "deprel": "nsubj",
#   "start_char": 65,
#   "end_char": 69
# }, {
#   "id": 12,
#   "text": "is",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBZ",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#   "head": 14,
#   "deprel": "cop",
#   "start_char": 70,
#   "end_char": 72
# }, {
#   "id": 13,
#   "text": "between",
#   "lemma": "between",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 14,
#   "deprel": "case",
#   "start_char": 73,
#   "end_char": 80
# }, {
#   "id": 14,
#   "text": "10",
#   "lemma": "10",
#   "upos": "NUM",
#   "xpos": "CD",
#   "feats": "NumType=Card",
#   "head": 9,
#   "deprel": "acl:relcl",
#   "start_char": 81,
#   "end_char": 83
# }, {
#   "id": 15,
#   "text": "and",
#   "lemma": "and",
#   "upos": "CCONJ",
#   "xpos": "CC",
#   "head": 16,
#   "deprel": "cc",
#   "start_char": 84,
#   "end_char": 87
# }, {
#   "id": 16,
#   "text": "15",
#   "lemma": "15",
#   "upos": "NUM",
#   "xpos": "CD",
#   "feats": "NumType=Card",
#   "head": 14,
#   "deprel": "conj",
#   "start_char": 88,
#   "end_char": 90
# }, {
#   "id": 17,
#   "text": "?",
#   "lemma": "?",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 0,
#   "deprel": "punct",
#   "start_char": 91,
#   "end_char": 92
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'0,1': 'F', '1,0': 'B', '4,2': 'F', '2,4': 'B', '4,3': 'F', '3,4': 'B', '0,4': 'F', '4,0': 'B', '6,5': 'F', '5,6': 'B', '4,6': 'F', '6,4': 'B', '9,7': 'F', '7,9': 'B', '9,8': 'F', '8,9': 'B', '6,9': 'F', '9,6': 'B', '11,10': 'F', '10,11': 'B', '14,11': 'F', '11,14': 'B', '14,12': 'F', '12,14': 'B', '14,13': 'F', '13,14': 'B', '9,14': 'F', '14,9': 'B', '16,15': 'F', '15,16': 'B', '14,16': 'F', '16,14': 'B', '0,17': 'F', '17,0': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'what', 'dep': 'attr', 'head': 1}
# {'id': 1, 'text': 'are', 'dep': 'ROOT', 'head': 1}
# {'id': 2, 'text': 'the', 'dep': 'det', 'head': 3}
# {'id': 3, 'text': 'names', 'dep': 'nsubj', 'head': 1}
# {'id': 4, 'text': 'of', 'dep': 'prep', 'head': 3}
# {'id': 5, 'text': 'the', 'dep': 'det', 'head': 6}
# {'id': 6, 'text': 'heads', 'dep': 'pobj', 'head': 4}
# {'id': 7, 'text': 'who', 'dep': 'nsubjpass', 'head': 9}
# {'id': 8, 'text': 'are', 'dep': 'auxpass', 'head': 9}
# {'id': 9, 'text': 'born', 'dep': 'relcl', 'head': 6}
# {'id': 10, 'text': 'outside', 'dep': 'prep', 'head': 9}
# {'id': 11, 'text': 'the', 'dep': 'det', 'head': 13}
# {'id': 12, 'text': 'california', 'dep': 'compound', 'head': 13}
# {'id': 13, 'text': 'state', 'dep': 'pobj', 'head': 10}
# {'id': 14, 'text': '?', 'dep': 'punct', 'head': 1}
# ------------------------------
# dp_link_spacy: {'dp_link': {'1,0': 'F', '0,1': 'B', '3,2': 'F', '2,3': 'B', '1,3': 'F', '3,1': 'B', '3,4': 'F', '4,3': 'B', '6,5': 'F', '5,6': 'B', '4,6': 'F', '6,4': 'B', '9,7': 'F', '7,9': 'B', '9,8': 'F', '8,9': 'B', '6,9': 'F', '9,6': 'B', '9,10': 'F', '10,9': 'B', '13,11': 'F', '11,13': 'B', '13,12': 'F', '12,13': 'B', '10,13': 'F', '13,10': 'B', '1,14': 'F', '14,1': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "what",
#   "lemma": "what",
#   "upos": "PRON",
#   "xpos": "WP",
#   "feats": "PronType=Int",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 0,
#   "end_char": 4
# }, {
#   "id": 1,
#   "text": "are",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBP",
#   "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#   "head": 0,
#   "deprel": "cop",
#   "start_char": 5,
#   "end_char": 8
# }, {
#   "id": 2,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 3,
#   "deprel": "det",
#   "start_char": 9,
#   "end_char": 12
# }, {
#   "id": 3,
#   "text": "names",
#   "lemma": "name",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 0,
#   "deprel": "nsubj",
#   "start_char": 13,
#   "end_char": 18
# }, {
#   "id": 4,
#   "text": "of",
#   "lemma": "of",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 6,
#   "deprel": "case",
#   "start_char": 19,
#   "end_char": 21
# }, {
#   "id": 5,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 6,
#   "deprel": "det",
#   "start_char": 22,
#   "end_char": 25
# }, {
#   "id": 6,
#   "text": "heads",
#   "lemma": "head",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 3,
#   "deprel": "nmod",
#   "start_char": 26,
#   "end_char": 31
# }, {
#   "id": 7,
#   "text": "who",
#   "lemma": "who",
#   "upos": "PRON",
#   "xpos": "WP",
#   "feats": "PronType=Rel",
#   "head": 9,
#   "deprel": "nsubj:pass",
#   "start_char": 32,
#   "end_char": 35
# }, {
#   "id": 8,
#   "text": "are",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBP",
#   "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#   "head": 9,
#   "deprel": "aux:pass",
#   "start_char": 36,
#   "end_char": 39
# }, {
#   "id": 9,
#   "text": "born",
#   "lemma": "bear",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 6,
#   "deprel": "acl:relcl",
#   "start_char": 40,
#   "end_char": 44
# }, {
#   "id": 10,
#   "text": "outside",
#   "lemma": "outside",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 13,
#   "deprel": "case",
#   "start_char": 45,
#   "end_char": 52
# }, {
#   "id": 11,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 13,
#   "deprel": "det",
#   "start_char": 53,
#   "end_char": 56
# }, {
#   "id": 12,
#   "text": "california",
#   "lemma": "california",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 13,
#   "deprel": "compound",
#   "start_char": 57,
#   "end_char": 67
# }, {
#   "id": 13,
#   "text": "state",
#   "lemma": "state",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 9,
#   "deprel": "obl",
#   "start_char": 68,
#   "end_char": 73
# }, {
#   "id": 14,
#   "text": "?",
#   "lemma": "?",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 0,
#   "deprel": "punct",
#   "start_char": 74,
#   "end_char": 75
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'0,1': 'F', '1,0': 'B', '3,2': 'F', '2,3': 'B', '0,3': 'F', '3,0': 'B', '6,4': 'F', '4,6': 'B', '6,5': 'F', '5,6': 'B', '3,6': 'F', '6,3': 'B', '9,7': 'F', '7,9': 'B', '9,8': 'F', '8,9': 'B', '6,9': 'F', '9,6': 'B', '13,10': 'F', '10,13': 'B', '13,11': 'F', '11,13': 'B', '13,12': 'F', '12,13': 'B', '9,13': 'F', '13,9': 'B', '0,14': 'F', '14,0': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'what', 'dep': 'attr', 'head': 1}
# {'id': 1, 'text': 'are', 'dep': 'ROOT', 'head': 1}
# {'id': 2, 'text': 'the', 'dep': 'det', 'head': 5}
# {'id': 3, 'text': 'distinct', 'dep': 'amod', 'head': 5}
# {'id': 4, 'text': 'creation', 'dep': 'compound', 'head': 5}
# {'id': 5, 'text': 'years', 'dep': 'nsubj', 'head': 1}
# {'id': 6, 'text': 'of', 'dep': 'prep', 'head': 5}
# {'id': 7, 'text': 'the', 'dep': 'det', 'head': 8}
# {'id': 8, 'text': 'departments', 'dep': 'pobj', 'head': 6}
# {'id': 9, 'text': 'managed', 'dep': 'acl', 'head': 8}
# {'id': 10, 'text': 'by', 'dep': 'agent', 'head': 9}
# {'id': 11, 'text': 'a', 'dep': 'det', 'head': 12}
# {'id': 12, 'text': 'secretary', 'dep': 'pobj', 'head': 10}
# {'id': 13, 'text': 'born', 'dep': 'acl', 'head': 12}
# {'id': 14, 'text': 'in', 'dep': 'prep', 'head': 13}
# {'id': 15, 'text': 'state', 'dep': 'poss', 'head': 17}
# {'id': 16, 'text': "'", 'dep': 'case', 'head': 15}
# {'id': 17, 'text': 'alabama', 'dep': 'pobj', 'head': 14}
# {'id': 18, 'text': "'", 'dep': 'punct', 'head': 1}
# {'id': 19, 'text': '?', 'dep': 'punct', 'head': 1}
# ------------------------------
# dp_link_spacy: {'dp_link': {'1,0': 'F', '0,1': 'B', '5,2': 'F', '2,5': 'B', '5,3': 'F', '3,5': 'B', '5,4': 'F', '4,5': 'B', '1,5': 'F', '5,1': 'B', '5,6': 'F', '6,5': 'B', '8,7': 'F', '7,8': 'B', '6,8': 'F', '8,6': 'B', '8,9': 'F', '9,8': 'B', '9,10': 'F', '10,9': 'B', '12,11': 'F', '11,12': 'B', '10,12': 'F', '12,10': 'B', '12,13': 'F', '13,12': 'B', '13,14': 'F', '14,13': 'B', '17,15': 'F', '15,17': 'B', '15,16': 'F', '16,15': 'B', '14,17': 'F', '17,14': 'B', '1,18': 'F', '18,1': 'B', '1,19': 'F', '19,1': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "what",
#   "lemma": "what",
#   "upos": "PRON",
#   "xpos": "WP",
#   "feats": "PronType=Int",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 0,
#   "end_char": 4
# }, {
#   "id": 1,
#   "text": "are",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBP",
#   "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#   "head": 0,
#   "deprel": "cop",
#   "start_char": 5,
#   "end_char": 8
# }, {
#   "id": 2,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 5,
#   "deprel": "det",
#   "start_char": 9,
#   "end_char": 12
# }, {
#   "id": 3,
#   "text": "distinct",
#   "lemma": "distinct",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 5,
#   "deprel": "amod",
#   "start_char": 13,
#   "end_char": 21
# }, {
#   "id": 4,
#   "text": "creation",
#   "lemma": "creation",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 5,
#   "deprel": "compound",
#   "start_char": 22,
#   "end_char": 30
# }, {
#   "id": 5,
#   "text": "years",
#   "lemma": "year",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 0,
#   "deprel": "nsubj",
#   "start_char": 31,
#   "end_char": 36
# }, {
#   "id": 6,
#   "text": "of",
#   "lemma": "of",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 8,
#   "deprel": "case",
#   "start_char": 37,
#   "end_char": 39
# }, {
#   "id": 7,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 8,
#   "deprel": "det",
#   "start_char": 40,
#   "end_char": 43
# }, {
#   "id": 8,
#   "text": "departments",
#   "lemma": "department",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 5,
#   "deprel": "nmod",
#   "start_char": 44,
#   "end_char": 55
# }, {
#   "id": 9,
#   "text": "managed",
#   "lemma": "manage",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 8,
#   "deprel": "acl",
#   "start_char": 56,
#   "end_char": 63
# }, {
#   "id": 10,
#   "text": "by",
#   "lemma": "by",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 12,
#   "deprel": "case",
#   "start_char": 64,
#   "end_char": 66
# }, {
#   "id": 11,
#   "text": "a",
#   "lemma": "a",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Ind|PronType=Art",
#   "head": 12,
#   "deprel": "det",
#   "start_char": 67,
#   "end_char": 68
# }, {
#   "id": 12,
#   "text": "secretary",
#   "lemma": "secretary",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 9,
#   "deprel": "obl",
#   "start_char": 69,
#   "end_char": 78
# }, {
#   "id": 13,
#   "text": "born",
#   "lemma": "bear",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 12,
#   "deprel": "acl",
#   "start_char": 79,
#   "end_char": 83
# }, {
#   "id": 14,
#   "text": "in",
#   "lemma": "in",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 15,
#   "deprel": "case",
#   "start_char": 84,
#   "end_char": 86
# }, {
#   "id": 15,
#   "text": "state",
#   "lemma": "state",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 13,
#   "deprel": "obl",
#   "start_char": 87,
#   "end_char": 92
# }, {
#   "id": 16,
#   "text": "'",
#   "lemma": "'",
#   "upos": "PUNCT",
#   "xpos": "``",
#   "head": 17,
#   "deprel": "punct",
#   "start_char": 93,
#   "end_char": 94
# }, {
#   "id": 17,
#   "text": "alabama",
#   "lemma": "alabama",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 15,
#   "deprel": "appos",
#   "start_char": 95,
#   "end_char": 102
# }, {
#   "id": 18,
#   "text": "'",
#   "lemma": "'",
#   "upos": "PUNCT",
#   "xpos": "''",
#   "head": 17,
#   "deprel": "punct",
#   "start_char": 103,
#   "end_char": 104
# }, {
#   "id": 19,
#   "text": "?",
#   "lemma": "?",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 0,
#   "deprel": "punct",
#   "start_char": 105,
#   "end_char": 106
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'0,1': 'F', '1,0': 'B', '5,2': 'F', '2,5': 'B', '5,3': 'F', '3,5': 'B', '5,4': 'F', '4,5': 'B', '0,5': 'F', '5,0': 'B', '8,6': 'F', '6,8': 'B', '8,7': 'F', '7,8': 'B', '5,8': 'F', '8,5': 'B', '8,9': 'F', '9,8': 'B', '12,10': 'F', '10,12': 'B', '12,11': 'F', '11,12': 'B', '9,12': 'F', '12,9': 'B', '12,13': 'F', '13,12': 'B', '15,14': 'F', '14,15': 'B', '13,15': 'F', '15,13': 'B', '17,16': 'F', '16,17': 'B', '15,17': 'F', '17,15': 'B', '17,18': 'F', '18,17': 'B', '0,19': 'F', '19,0': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'what', 'dep': 'attr', 'head': 1}
# {'id': 1, 'text': 'are', 'dep': 'ROOT', 'head': 1}
# {'id': 2, 'text': 'the', 'dep': 'det', 'head': 3}
# {'id': 3, 'text': 'names', 'dep': 'nsubj', 'head': 1}
# {'id': 4, 'text': 'of', 'dep': 'prep', 'head': 3}
# {'id': 5, 'text': 'the', 'dep': 'det', 'head': 6}
# {'id': 6, 'text': 'states', 'dep': 'pobj', 'head': 4}
# {'id': 7, 'text': 'where', 'dep': 'advmod', 'head': 13}
# {'id': 8, 'text': 'at', 'dep': 'advmod', 'head': 9}
# {'id': 9, 'text': 'least', 'dep': 'advmod', 'head': 10}
# {'id': 10, 'text': '3', 'dep': 'nummod', 'head': 11}
# {'id': 11, 'text': 'heads', 'dep': 'nsubjpass', 'head': 13}
# {'id': 12, 'text': 'were', 'dep': 'auxpass', 'head': 13}
# {'id': 13, 'text': 'born', 'dep': 'relcl', 'head': 6}
# {'id': 14, 'text': '?', 'dep': 'punct', 'head': 1}
# ------------------------------
# dp_link_spacy: {'dp_link': {'1,0': 'F', '0,1': 'B', '3,2': 'F', '2,3': 'B', '1,3': 'F', '3,1': 'B', '3,4': 'F', '4,3': 'B', '6,5': 'F', '5,6': 'B', '4,6': 'F', '6,4': 'B', '13,7': 'F', '7,13': 'B', '9,8': 'F', '8,9': 'B', '10,9': 'F', '9,10': 'B', '11,10': 'F', '10,11': 'B', '13,11': 'F', '11,13': 'B', '13,12': 'F', '12,13': 'B', '6,13': 'F', '13,6': 'B', '1,14': 'F', '14,1': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "what",
#   "lemma": "what",
#   "upos": "PRON",
#   "xpos": "WP",
#   "feats": "PronType=Int",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 0,
#   "end_char": 4
# }, {
#   "id": 1,
#   "text": "are",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBP",
#   "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#   "head": 0,
#   "deprel": "cop",
#   "start_char": 5,
#   "end_char": 8
# }, {
#   "id": 2,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 3,
#   "deprel": "det",
#   "start_char": 9,
#   "end_char": 12
# }, {
#   "id": 3,
#   "text": "names",
#   "lemma": "name",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 0,
#   "deprel": "nsubj",
#   "start_char": 13,
#   "end_char": 18
# }, {
#   "id": 4,
#   "text": "of",
#   "lemma": "of",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 6,
#   "deprel": "case",
#   "start_char": 19,
#   "end_char": 21
# }, {
#   "id": 5,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 6,
#   "deprel": "det",
#   "start_char": 22,
#   "end_char": 25
# }, {
#   "id": 6,
#   "text": "states",
#   "lemma": "state",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 3,
#   "deprel": "nmod",
#   "start_char": 26,
#   "end_char": 32
# }, {
#   "id": 7,
#   "text": "where",
#   "lemma": "where",
#   "upos": "SCONJ",
#   "xpos": "WRB",
#   "feats": "PronType=Int",
#   "head": 13,
#   "deprel": "mark",
#   "start_char": 33,
#   "end_char": 38
# }, {
#   "id": 8,
#   "text": "at",
#   "lemma": "at",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 9,
#   "deprel": "case",
#   "start_char": 39,
#   "end_char": 41
# }, {
#   "id": 9,
#   "text": "least",
#   "lemma": "least",
#   "upos": "ADJ",
#   "xpos": "JJS",
#   "feats": "Degree=Sup",
#   "head": 10,
#   "deprel": "nmod",
#   "start_char": 42,
#   "end_char": 47
# }, {
#   "id": 10,
#   "text": "3",
#   "lemma": "3",
#   "upos": "NUM",
#   "xpos": "CD",
#   "feats": "NumType=Card",
#   "head": 11,
#   "deprel": "nummod",
#   "start_char": 48,
#   "end_char": 49
# }, {
#   "id": 11,
#   "text": "heads",
#   "lemma": "head",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 13,
#   "deprel": "nsubj:pass",
#   "start_char": 50,
#   "end_char": 55
# }, {
#   "id": 12,
#   "text": "were",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBD",
#   "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#   "head": 13,
#   "deprel": "aux:pass",
#   "start_char": 56,
#   "end_char": 60
# }, {
#   "id": 13,
#   "text": "born",
#   "lemma": "bear",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part|Voice=Pass",
#   "head": 6,
#   "deprel": "acl:relcl",
#   "start_char": 61,
#   "end_char": 65
# }, {
#   "id": 14,
#   "text": "?",
#   "lemma": "?",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 0,
#   "deprel": "punct",
#   "start_char": 66,
#   "end_char": 67
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'0,1': 'F', '1,0': 'B', '3,2': 'F', '2,3': 'B', '0,3': 'F', '3,0': 'B', '6,4': 'F', '4,6': 'B', '6,5': 'F', '5,6': 'B', '3,6': 'F', '6,3': 'B', '13,7': 'F', '7,13': 'B', '9,8': 'F', '8,9': 'B', '10,9': 'F', '9,10': 'B', '11,10': 'F', '10,11': 'B', '13,11': 'F', '11,13': 'B', '13,12': 'F', '12,13': 'B', '6,13': 'F', '13,6': 'B', '0,14': 'F', '14,0': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'in', 'dep': 'prep', 'head': 3}
# {'id': 1, 'text': 'which', 'dep': 'det', 'head': 2}
# {'id': 2, 'text': 'year', 'dep': 'pcomp', 'head': 0}
# {'id': 3, 'text': 'were', 'dep': 'ROOT', 'head': 3}
# {'id': 4, 'text': 'most', 'dep': 'amod', 'head': 5}
# {'id': 5, 'text': 'departments', 'dep': 'attr', 'head': 3}
# {'id': 6, 'text': 'established', 'dep': 'acl', 'head': 5}
# {'id': 7, 'text': '?', 'dep': 'punct', 'head': 3}
# ------------------------------
# dp_link_spacy: {'dp_link': {'3,0': 'F', '0,3': 'B', '2,1': 'F', '1,2': 'B', '0,2': 'F', '2,0': 'B', '5,4': 'F', '4,5': 'B', '3,5': 'F', '5,3': 'B', '5,6': 'F', '6,5': 'B', '3,7': 'F', '7,3': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "in",
#   "lemma": "in",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 2,
#   "deprel": "case",
#   "start_char": 0,
#   "end_char": 2
# }, {
#   "id": 1,
#   "text": "which",
#   "lemma": "which",
#   "upos": "DET",
#   "xpos": "WDT",
#   "feats": "PronType=Int",
#   "head": 2,
#   "deprel": "det",
#   "start_char": 3,
#   "end_char": 8
# }, {
#   "id": 2,
#   "text": "year",
#   "lemma": "year",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 6,
#   "deprel": "obl",
#   "start_char": 9,
#   "end_char": 13
# }, {
#   "id": 3,
#   "text": "were",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBD",
#   "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#   "head": 6,
#   "deprel": "aux:pass",
#   "start_char": 14,
#   "end_char": 18
# }, {
#   "id": 4,
#   "text": "most",
#   "lemma": "most",
#   "upos": "ADJ",
#   "xpos": "JJS",
#   "feats": "Degree=Sup",
#   "head": 5,
#   "deprel": "amod",
#   "start_char": 19,
#   "end_char": 23
# }, {
#   "id": 5,
#   "text": "departments",
#   "lemma": "department",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 6,
#   "deprel": "nsubj:pass",
#   "start_char": 24,
#   "end_char": 35
# }, {
#   "id": 6,
#   "text": "established",
#   "lemma": "establish",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 36,
#   "end_char": 47
# }, {
#   "id": 7,
#   "text": "?",
#   "lemma": "?",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 6,
#   "deprel": "punct",
#   "start_char": 48,
#   "end_char": 49
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'2,0': 'F', '0,2': 'B', '2,1': 'F', '1,2': 'B', '6,2': 'F', '2,6': 'B', '6,3': 'F', '3,6': 'B', '5,4': 'F', '4,5': 'B', '6,5': 'F', '5,6': 'B', '6,7': 'F', '7,6': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'show', 'dep': 'ROOT', 'head': 0}
# {'id': 1, 'text': 'the', 'dep': 'det', 'head': 2}
# {'id': 2, 'text': 'name', 'dep': 'dobj', 'head': 0}
# {'id': 3, 'text': 'and', 'dep': 'cc', 'head': 2}
# {'id': 4, 'text': 'number', 'dep': 'conj', 'head': 2}
# {'id': 5, 'text': 'of', 'dep': 'prep', 'head': 2}
# {'id': 6, 'text': 'employees', 'dep': 'pobj', 'head': 5}
# {'id': 7, 'text': 'for', 'dep': 'prep', 'head': 6}
# {'id': 8, 'text': 'the', 'dep': 'det', 'head': 9}
# {'id': 9, 'text': 'departments', 'dep': 'pobj', 'head': 7}
# {'id': 10, 'text': 'managed', 'dep': 'acl', 'head': 9}
# {'id': 11, 'text': 'by', 'dep': 'agent', 'head': 10}
# {'id': 12, 'text': 'heads', 'dep': 'pobj', 'head': 11}
# {'id': 13, 'text': 'whose', 'dep': 'poss', 'head': 16}
# {'id': 14, 'text': 'temporary', 'dep': 'amod', 'head': 16}
# {'id': 15, 'text': 'acting', 'dep': 'amod', 'head': 16}
# {'id': 16, 'text': 'value', 'dep': 'nsubj', 'head': 17}
# {'id': 17, 'text': 'is', 'dep': 'conj', 'head': 0}
# {'id': 18, 'text': "'", 'dep': 'punct', 'head': 17}
# {'id': 19, 'text': 'yes', 'dep': 'intj', 'head': 17}
# {'id': 20, 'text': "'", 'dep': 'punct', 'head': 17}
# {'id': 21, 'text': '?', 'dep': 'punct', 'head': 17}
# ------------------------------
# dp_link_spacy: {'dp_link': {'2,1': 'F', '1,2': 'B', '0,2': 'F', '2,0': 'B', '2,3': 'F', '3,2': 'B', '2,4': 'F', '4,2': 'B', '2,5': 'F', '5,2': 'B', '5,6': 'F', '6,5': 'B', '6,7': 'F', '7,6': 'B', '9,8': 'F', '8,9': 'B', '7,9': 'F', '9,7': 'B', '9,10': 'F', '10,9': 'B', '10,11': 'F', '11,10': 'B', '11,12': 'F', '12,11': 'B', '16,13': 'F', '13,16': 'B', '16,14': 'F', '14,16': 'B', '16,15': 'F', '15,16': 'B', '17,16': 'F', '16,17': 'B', '0,17': 'F', '17,0': 'B', '17,18': 'F', '18,17': 'B', '17,19': 'F', '19,17': 'B', '17,20': 'F', '20,17': 'B', '17,21': 'F', '21,17': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "show",
#   "lemma": "show",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "Mood=Imp|VerbForm=Fin",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 0,
#   "end_char": 4
# }, {
#   "id": 1,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 2,
#   "deprel": "det",
#   "start_char": 5,
#   "end_char": 8
# }, {
#   "id": 2,
#   "text": "name",
#   "lemma": "name",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 0,
#   "deprel": "obj",
#   "start_char": 9,
#   "end_char": 13
# }, {
#   "id": 3,
#   "text": "and",
#   "lemma": "and",
#   "upos": "CCONJ",
#   "xpos": "CC",
#   "head": 4,
#   "deprel": "cc",
#   "start_char": 14,
#   "end_char": 17
# }, {
#   "id": 4,
#   "text": "number",
#   "lemma": "number",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 2,
#   "deprel": "conj",
#   "start_char": 18,
#   "end_char": 24
# }, {
#   "id": 5,
#   "text": "of",
#   "lemma": "of",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 6,
#   "deprel": "case",
#   "start_char": 25,
#   "end_char": 27
# }, {
#   "id": 6,
#   "text": "employees",
#   "lemma": "employee",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 2,
#   "deprel": "nmod",
#   "start_char": 28,
#   "end_char": 37
# }, {
#   "id": 7,
#   "text": "for",
#   "lemma": "for",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 9,
#   "deprel": "case",
#   "start_char": 38,
#   "end_char": 41
# }, {
#   "id": 8,
#   "text": "the",
#   "lemma": "the",
#   "upos": "DET",
#   "xpos": "DT",
#   "feats": "Definite=Def|PronType=Art",
#   "head": 9,
#   "deprel": "det",
#   "start_char": 42,
#   "end_char": 45
# }, {
#   "id": 9,
#   "text": "departments",
#   "lemma": "department",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 6,
#   "deprel": "nmod",
#   "start_char": 46,
#   "end_char": 57
# }, {
#   "id": 10,
#   "text": "managed",
#   "lemma": "manage",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 9,
#   "deprel": "acl",
#   "start_char": 58,
#   "end_char": 65
# }, {
#   "id": 11,
#   "text": "by",
#   "lemma": "by",
#   "upos": "ADP",
#   "xpos": "IN",
#   "head": 12,
#   "deprel": "case",
#   "start_char": 66,
#   "end_char": 68
# }, {
#   "id": 12,
#   "text": "heads",
#   "lemma": "head",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 10,
#   "deprel": "obl",
#   "start_char": 69,
#   "end_char": 74
# }, {
#   "id": 13,
#   "text": "whose",
#   "lemma": "whose",
#   "upos": "PRON",
#   "xpos": "WP$",
#   "feats": "Poss=Yes|PronType=Int",
#   "head": 16,
#   "deprel": "nmod:poss",
#   "start_char": 75,
#   "end_char": 80
# }, {
#   "id": 14,
#   "text": "temporary",
#   "lemma": "temporary",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 16,
#   "deprel": "amod",
#   "start_char": 81,
#   "end_char": 90
# }, {
#   "id": 15,
#   "text": "acting",
#   "lemma": "acting",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 16,
#   "deprel": "compound",
#   "start_char": 91,
#   "end_char": 97
# }, {
#   "id": 16,
#   "text": "value",
#   "lemma": "value",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 17,
#   "deprel": "nsubj",
#   "start_char": 98,
#   "end_char": 103
# }, {
#   "id": 17,
#   "text": "is",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBZ",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#   "head": 12,
#   "deprel": "acl:relcl",
#   "start_char": 104,
#   "end_char": 106
# }, {
#   "id": 18,
#   "text": "'",
#   "lemma": "'",
#   "upos": "PUNCT",
#   "xpos": "``",
#   "head": 19,
#   "deprel": "punct",
#   "start_char": 107,
#   "end_char": 108
# }, {
#   "id": 19,
#   "text": "yes",
#   "lemma": "yes",
#   "upos": "INTJ",
#   "xpos": "UH",
#   "head": 17,
#   "deprel": "ccomp",
#   "start_char": 109,
#   "end_char": 112
# }, {
#   "id": 20,
#   "text": "'",
#   "lemma": "'",
#   "upos": "PUNCT",
#   "xpos": "''",
#   "head": 19,
#   "deprel": "punct",
#   "start_char": 113,
#   "end_char": 114
# }, {
#   "id": 21,
#   "text": "?",
#   "lemma": "?",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 0,
#   "deprel": "punct",
#   "start_char": 115,
#   "end_char": 116
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'2,1': 'F', '1,2': 'B', '0,2': 'F', '2,0': 'B', '4,3': 'F', '3,4': 'B', '2,4': 'F', '4,2': 'B', '6,5': 'F', '5,6': 'B', '2,6': 'F', '6,2': 'B', '9,7': 'F', '7,9': 'B', '9,8': 'F', '8,9': 'B', '6,9': 'F', '9,6': 'B', '9,10': 'F', '10,9': 'B', '12,11': 'F', '11,12': 'B', '10,12': 'F', '12,10': 'B', '16,13': 'F', '13,16': 'B', '16,14': 'F', '14,16': 'B', '16,15': 'F', '15,16': 'B', '17,16': 'F', '16,17': 'B', '12,17': 'F', '17,12': 'B', '19,18': 'F', '18,19': 'B', '17,19': 'F', '19,17': 'B', '19,20': 'F', '20,19': 'B', '0,21': 'F', '21,0': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'how', 'dep': 'advmod', 'head': 1}
# {'id': 1, 'text': 'many', 'dep': 'amod', 'head': 3}
# {'id': 2, 'text': 'acting', 'dep': 'amod', 'head': 3}
# {'id': 3, 'text': 'status', 'dep': 'nsubj', 'head': 7}
# {'id': 4, 'text': '#', 'dep': 'nmod', 'head': 5}
# {'id': 5, 'text': '#', 'dep': 'appos', 'head': 3}
# {'id': 6, 'text': 'es', 'dep': 'intj', 'head': 3}
# {'id': 7, 'text': 'are', 'dep': 'ROOT', 'head': 7}
# {'id': 8, 'text': 'there', 'dep': 'advmod', 'head': 7}
# {'id': 9, 'text': '?', 'dep': 'punct', 'head': 7}
# ------------------------------
# dp_link_spacy: {'dp_link': {'1,0': 'F', '0,1': 'B', '3,1': 'F', '1,3': 'B', '3,2': 'F', '2,3': 'B', '7,3': 'F', '3,7': 'B', '5,4': 'F', '4,5': 'B', '3,5': 'F', '5,3': 'B', '3,6': 'F', '6,3': 'B', '7,8': 'F', '8,7': 'B', '7,9': 'F', '9,7': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "how",
#   "lemma": "how",
#   "upos": "ADV",
#   "xpos": "WRB",
#   "feats": "PronType=Int",
#   "head": 1,
#   "deprel": "advmod",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "id": 1,
#   "text": "many",
#   "lemma": "many",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 6,
#   "deprel": "amod",
#   "start_char": 4,
#   "end_char": 8
# }, {
#   "id": 2,
#   "text": "acting",
#   "lemma": "acting",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 3,
#   "deprel": "compound",
#   "start_char": 9,
#   "end_char": 15
# }, {
#   "id": 3,
#   "text": "status",
#   "lemma": "status",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 6,
#   "deprel": "compound",
#   "start_char": 16,
#   "end_char": 22
# }, {
#   "id": 4,
#   "text": "#",
#   "lemma": "#",
#   "upos": "SYM",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 6,
#   "deprel": "compound",
#   "start_char": 23,
#   "end_char": 24
# }, {
#   "id": 5,
#   "text": "#",
#   "lemma": "#",
#   "upos": "SYM",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 6,
#   "deprel": "compound",
#   "start_char": 24,
#   "end_char": 25
# }, {
#   "id": 6,
#   "text": "es",
#   "lemma": "es",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 8,
#   "deprel": "nsubj",
#   "start_char": 25,
#   "end_char": 27
# }, {
#   "id": 7,
#   "text": "are",
#   "lemma": "be",
#   "upos": "AUX",
#   "xpos": "VBP",
#   "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#   "head": 8,
#   "deprel": "cop",
#   "start_char": 28,
#   "end_char": 31
# }, {
#   "id": 8,
#   "text": "there",
#   "lemma": "there",
#   "upos": "ADV",
#   "xpos": "RB",
#   "feats": "PronType=Dem",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 32,
#   "end_char": 37
# }, {
#   "id": 9,
#   "text": "?",
#   "lemma": "?",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 8,
#   "deprel": "punct",
#   "start_char": 38,
#   "end_char": 39
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'1,0': 'F', '0,1': 'B', '6,1': 'F', '1,6': 'B', '3,2': 'F', '2,3': 'B', '6,3': 'F', '3,6': 'B', '6,4': 'F', '4,6': 'B', '6,5': 'F', '5,6': 'B', '8,6': 'F', '6,8': 'B', '8,7': 'F', '7,8': 'B', '8,9': 'F', '9,8': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'how', 'dep': 'advmod', 'head': 1}
# {'id': 1, 'text': 'many', 'dep': 'amod', 'head': 2}
# {'id': 2, 'text': 'departments', 'dep': 'nsubjpass', 'head': 4}
# {'id': 3, 'text': 'are', 'dep': 'auxpass', 'head': 4}
# {'id': 4, 'text': 'led', 'dep': 'ROOT', 'head': 4}
# {'id': 5, 'text': 'by', 'dep': 'agent', 'head': 4}
# ...
#   "end_char": 35
# }, {
#   "id": 8,
#   "text": "#",
#   "lemma": "#",
#   "upos": "SYM",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 11,
#   "deprel": "compound",
#   "start_char": 36,
#   "end_char": 37
# }, {
#   "id": 9,
#   "text": "#",
#   "lemma": "#",
#   "upos": "SYM",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 11,
#   "deprel": "compound",
#   "start_char": 37,
#   "end_char": 38
# }, {
#   "id": 10,
#   "text": "smith",
#   "lemma": "smith",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 11,
#   "deprel": "compound",
#   "start_char": 38,
#   "end_char": 43
# }, {
#   "id": 11,
#   "text": "albums",
#   "lemma": "album",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 3,
#   "deprel": "nmod",
#   "start_char": 44,
#   "end_char": 50
# }, {
#   "id": 12,
#   "text": "?",
#   "lemma": "?",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 0,
#   "deprel": "punct",
#   "start_char": 51,
#   "end_char": 52
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'0,1': 'F', '1,0': 'B', '3,2': 'F', '2,3': 'B', '0,3': 'F', '3,0': 'B', '11,4': 'F', '4,11': 'B', '11,5': 'F', '5,11': 'B', '11,6': 'F', '6,11': 'B', '11,7': 'F', '7,11': 'B', '11,8': 'F', '8,11': 'B', '11,9': 'F', '9,11': 'B', '11,10': 'F', '10,11': 'B', '3,11': 'F', '11,3': 'B', '0,12': 'F', '12,0': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'how', 'dep': 'advmod', 'head': 1}
# {'id': 1, 'text': 'many', 'dep': 'amod', 'head': 2}
# {'id': 2, 'text': 'albums', 'dep': 'nsubj', 'head': 5}
# {'id': 3, 'text': 'does', 'dep': 'aux', 'head': 5}
# {'id': 4, 'text': 'billy', 'dep': 'advmod', 'head': 5}
# {'id': 5, 'text': 'co', 'dep': 'ROOT', 'head': 5}
# {'id': 6, 'text': '#', 'dep': 'nmod', 'head': 7}
# {'id': 7, 'text': '#', 'dep': 'dobj', 'head': 9}
# {'id': 8, 'text': 'bham', 'dep': 'nsubj', 'head': 9}
# {'id': 9, 'text': 'has', 'dep': 'dep', 'head': 5}
# {'id': 10, 'text': '?', 'dep': 'punct', 'head': 5}
# ------------------------------
# dp_link_spacy: {'dp_link': {'1,0': 'F', '0,1': 'B', '2,1': 'F', '1,2': 'B', '5,2': 'F', '2,5': 'B', '5,3': 'F', '3,5': 'B', '5,4': 'F', '4,5': 'B', '7,6': 'F', '6,7': 'B', '9,7': 'F', '7,9': 'B', '9,8': 'F', '8,9': 'B', '5,9': 'F', '9,5': 'B', '5,10': 'F', '10,5': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "how",
#   "lemma": "how",
#   "upos": "ADV",
#   "xpos": "WRB",
#   "feats": "PronType=Int",
#   "head": 1,
#   "deprel": "advmod",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "id": 1,
#   "text": "many",
#   "lemma": "many",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 2,
#   "deprel": "amod",
#   "start_char": 4,
#   "end_char": 8
# }, {
#   "id": 2,
#   "text": "albums",
#   "lemma": "album",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 5,
#   "deprel": "obj",
#   "start_char": 9,
#   "end_char": 15
# }, {
#   "id": 3,
#   "text": "does",
#   "lemma": "do",
#   "upos": "AUX",
#   "xpos": "VBZ",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#   "head": 5,
#   "deprel": "aux",
#   "start_char": 16,
#   "end_char": 20
# }, {
#   "id": 4,
#   "text": "billy",
#   "lemma": "billy",
#   "upos": "PROPN",
#   "xpos": "NNP",
#   "feats": "Number=Sing",
#   "head": 5,
#   "deprel": "nsubj",
#   "start_char": 21,
#   "end_char": 26
# }, {
#   "id": 5,
#   "text": "co",
#   "lemma": "co",
#   "upos": "VERB",
#   "xpos": "VB",
#   "feats": "VerbForm=Inf",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 27,
#   "end_char": 29
# }, {
#   "id": 6,
#   "text": "##",
#   "lemma": "##",
#   "upos": "PUNCT",
#   "xpos": ",",
#   "head": 5,
#   "deprel": "punct",
#   "start_char": 30,
#   "end_char": 32
# }, {
#   "id": 7,
#   "text": "bham",
#   "lemma": "bham",
#   "upos": "PRON",
#   "xpos": "PRP",
#   "feats": "Number=Sing|PronType=Prs",
#   "head": 8,
#   "deprel": "nsubj",
#   "start_char": 32,
#   "end_char": 36
# }, {
#   "id": 8,
#   "text": "has",
#   "lemma": "have",
#   "upos": "VERB",
#   "xpos": "VBZ",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#   "head": 5,
#   "deprel": "parataxis",
#   "start_char": 37,
#   "end_char": 40
# }, {
#   "id": 9,
#   "text": "?",
#   "lemma": "?",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 5,
#   "deprel": "punct",
#   "start_char": 41,
#   "end_char": 42
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'1,0': 'F', '0,1': 'B', '2,1': 'F', '1,2': 'B', '5,2': 'F', '2,5': 'B', '5,3': 'F', '3,5': 'B', '5,4': 'F', '4,5': 'B', '5,6': 'F', '6,5': 'B', '8,7': 'F', '7,8': 'B', '5,8': 'F', '8,5': 'B', '5,9': 'F', '9,5': 'B'}}
# ==============================
# words_spacy:
# {'id': 0, 'text': 'how', 'dep': 'advmod', 'head': 1}
# {'id': 1, 'text': 'many', 'dep': 'amod', 'head': 2}
# {'id': 2, 'text': 'albums', 'dep': 'nsubj', 'head': 5}
# {'id': 3, 'text': 'has', 'dep': 'aux', 'head': 5}
# {'id': 4, 'text': 'billy', 'dep': 'advmod', 'head': 5}
# {'id': 5, 'text': 'co', 'dep': 'ROOT', 'head': 5}
# {'id': 6, 'text': '#', 'dep': 'nmod', 'head': 7}
# {'id': 7, 'text': '#', 'dep': 'npadvmod', 'head': 5}
# {'id': 8, 'text': 'ba', 'dep': 'dobj', 'head': 5}
# {'id': 9, 'text': '#', 'dep': 'nmod', 'head': 10}
# {'id': 10, 'text': '#', 'dep': 'npadvmod', 'head': 5}
# {'id': 11, 'text': 'm', 'dep': 'auxpass', 'head': 12}
# {'id': 12, 'text': 'released', 'dep': 'advcl', 'head': 5}
# {'id': 13, 'text': '?', 'dep': 'punct', 'head': 5}
# ------------------------------
# dp_link_spacy: {'dp_link': {'1,0': 'F', '0,1': 'B', '2,1': 'F', '1,2': 'B', '5,2': 'F', '2,5': 'B', '5,3': 'F', '3,5': 'B', '5,4': 'F', '4,5': 'B', '7,6': 'F', '6,7': 'B', '5,7': 'F', '7,5': 'B', '5,8': 'F', '8,5': 'B', '10,9': 'F', '9,10': 'B', '5,10': 'F', '10,5': 'B', '12,11': 'F', '11,12': 'B', '5,12': 'F', '12,5': 'B', '5,13': 'F', '13,5': 'B'}}
# ==============================
# words_stanza: [{
#   "id": 0,
#   "text": "how",
#   "lemma": "how",
#   "upos": "ADV",
#   "xpos": "WRB",
#   "feats": "PronType=Int",
#   "head": 1,
#   "deprel": "advmod",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "id": 1,
#   "text": "many",
#   "lemma": "many",
#   "upos": "ADJ",
#   "xpos": "JJ",
#   "feats": "Degree=Pos",
#   "head": 2,
#   "deprel": "amod",
#   "start_char": 4,
#   "end_char": 8
# }, {
#   "id": 2,
#   "text": "albums",
#   "lemma": "album",
#   "upos": "NOUN",
#   "xpos": "NNS",
#   "feats": "Number=Plur",
#   "head": 3,
#   "deprel": "nsubj",
#   "start_char": 9,
#   "end_char": 15
# }, {
#   "id": 3,
#   "text": "has",
#   "lemma": "have",
#   "upos": "VERB",
#   "xpos": "VBZ",
#   "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#   "head": -1,
#   "deprel": "root",
#   "start_char": 16,
#   "end_char": 19
# }, {
#   "id": 4,
#   "text": "billy",
#   "lemma": "billy",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 5,
#   "deprel": "compound",
#   "start_char": 20,
#   "end_char": 25
# }, {
#   "id": 5,
#   "text": "co",
#   "lemma": "co",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 3,
#   "deprel": "obj",
#   "start_char": 26,
#   "end_char": 28
# }, {
#   "id": 6,
#   "text": "##",
#   "lemma": "##",
#   "upos": "PUNCT",
#   "xpos": ",",
#   "head": 7,
#   "deprel": "punct",
#   "start_char": 29,
#   "end_char": 31
# }, {
#   "id": 7,
#   "text": "ba",
#   "lemma": "ba",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 5,
#   "deprel": "appos",
#   "start_char": 31,
#   "end_char": 33
# }, {
#   "id": 8,
#   "text": "##",
#   "lemma": "##",
#   "upos": "SYM",
#   "xpos": "SYM",
#   "head": 9,
#   "deprel": "cc",
#   "start_char": 34,
#   "end_char": 36
# }, {
#   "id": 9,
#   "text": "m",
#   "lemma": "m",
#   "upos": "NOUN",
#   "xpos": "NN",
#   "feats": "Number=Sing",
#   "head": 7,
#   "deprel": "conj",
#   "start_char": 36,
#   "end_char": 37
# }, {
#   "id": 10,
#   "text": "released",
#   "lemma": "release",
#   "upos": "VERB",
#   "xpos": "VBN",
#   "feats": "Tense=Past|VerbForm=Part",
#   "head": 7,
#   "deprel": "acl",
#   "start_char": 38,
#   "end_char": 46
# }, {
#   "id": 11,
#   "text": "?",
#   "lemma": "?",
#   "upos": "PUNCT",
#   "xpos": ".",
#   "head": 3,
#   "deprel": "punct",
#   "start_char": 47,
#   "end_char": 48
# }]
# ------------------------------
# dp_link_stanza: {'dp_link': {'1,0': 'F', '0,1': 'B', '2,1': 'F', '1,2': 'B', '3,2': 'F', '2,3': 'B', '5,4': 'F', '4,5': 'B', '3,5': 'F', '5,3': 'B', '7,6': 'F', '6,7': 'B', '5,7': 'F', '7,5': 'B', '9,8': 'F', '8,9': 'B', '7,9': 'F', '9,7': 'B', '7,10': 'F', '10,7': 'B', '3,11': 'F', '11,3': 'B'}}
# ==============================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_22391/2999056929.py in <module>
#      14     dp_linkage_stanza, dp_linkage_spacy = {}, {}
#      15     doc_stanza = nlp_stanza(' '.join(qj))
# ---> 16     doc_spacy = nlp_spacy(' '.join(qj))
#      17
#      18     words_stanza = doc_stanza.sentences[0].words
#
# /opt/conda/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1018                 error_handler = proc.get_error_handler()
#    1019             try:
# -> 1020                 doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1021             except KeyError as e:
#    1022                 # This typically happens if a component is not initialized
#
# /opt/conda/lib/python3.7/site-packages/spacy/pipeline/trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# /opt/conda/lib/python3.7/site-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.predict()
#
# /opt/conda/lib/python3.7/site-packages/spacy/pipeline/transition_parser.pyx in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# /opt/conda/lib/python3.7/site-packages/thinc/model.py in predict(self, X)
#     313         only the output, instead of the `(output, callback)` tuple.
#     314         """
# --> 315         return self._func(self, X, is_train=False)[0]
#     316
#     317     def finish_update(self, optimizer: Optimizer) -> None:
#
# /opt/conda/lib/python3.7/site-packages/spacy/ml/tb_framework.py in forward(model, X, is_train)
#      36         unseen_classes=model.attrs["unseen_classes"],
#      37         train=is_train,
# ---> 38         has_upper=model.attrs["has_upper"],
#      39     )
#      40
#
# /opt/conda/lib/python3.7/site-packages/spacy/ml/parser_model.pyx in spacy.ml.parser_model.ParserStepModel.__init__()
#
# /opt/conda/lib/python3.7/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.7/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      53     callbacks = []
#      54     for layer in model.layers:
# ---> 55         Y, inc_layer_grad = layer(X, is_train=is_train)
#      56         callbacks.append(inc_layer_grad)
#      57         X = Y
#
# /opt/conda/lib/python3.7/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.7/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      53     callbacks = []
#      54     for layer in model.layers:
# ---> 55         Y, inc_layer_grad = layer(X, is_train=is_train)
#      56         callbacks.append(inc_layer_grad)
#      57         X = Y
#
# /opt/conda/lib/python3.7/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.7/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      53     callbacks = []
#      54     for layer in model.layers:
# ---> 55         Y, inc_layer_grad = layer(X, is_train=is_train)
#      56         callbacks.append(inc_layer_grad)
#      57         X = Y
#
# /opt/conda/lib/python3.7/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.7/site-packages/thinc/layers/with_array.py in forward(model, Xseq, is_train)
#      30 ) -> Tuple[SeqT, Callable]:
#      31     if isinstance(Xseq, Ragged):
# ---> 32         return cast(Tuple[SeqT, Callable], _ragged_forward(model, Xseq, is_train))
#      33     elif isinstance(Xseq, Padded):
#      34         return cast(Tuple[SeqT, Callable], _padded_forward(model, Xseq, is_train))
#
# /opt/conda/lib/python3.7/site-packages/thinc/layers/with_array.py in _ragged_forward(model, Xr, is_train)
#      85 ) -> Tuple[Ragged, Callable]:
#      86     layer: Model[ArrayXd, ArrayXd] = model.layers[0]
# ---> 87     Y, get_dX = layer(Xr.dataXd, is_train)
#      88
#      89     def backprop(dYr: Ragged) -> Ragged:
#
# /opt/conda/lib/python3.7/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.7/site-packages/thinc/layers/concatenate.py in forward(model, X, is_train)
#      42
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         data_l, backprop = _list_forward(model, X, Ys, callbacks, is_train)
#
# /opt/conda/lib/python3.7/site-packages/thinc/layers/concatenate.py in <listcomp>(.0)
#      42
#      43 def forward(model: Model[InT, OutT], X: InT, is_train: bool) -> Tuple[OutT, Callable]:
# ---> 44     Ys, callbacks = zip(*[layer(X, is_train=is_train) for layer in model.layers])
#      45     if isinstance(Ys[0], list):
#      46         data_l, backprop = _list_forward(model, X, Ys, callbacks, is_train)
#
# /opt/conda/lib/python3.7/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.7/site-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      53     callbacks = []
#      54     for layer in model.layers:
# ---> 55         Y, inc_layer_grad = layer(X, is_train=is_train)
#      56         callbacks.append(inc_layer_grad)
#      57         X = Y
#
# /opt/conda/lib/python3.7/site-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /opt/conda/lib/python3.7/site-packages/thinc/layers/hashembed.py in forward(model, ids, is_train)
#      59     model: Model[Ints1d, OutT], ids: Ints1d, is_train: bool
#      60 ) -> Tuple[OutT, Callable]:
# ---> 61     vectors = cast(Floats2d, model.get_param("E"))
#      62     nV = vectors.shape[0]
#      63     nO = vectors.shape[1]
#
# KeyboardInterrupt:

# %%
for i,j in zip(dp_whole_stanza, dp_whole_spacy):
    if i != j:
        print(f'stanza: {i}')
        print(f'spacy: {j}')
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Spacy Example

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

dp_whole_spacy = []

for qj in train_data_qj:
    doc = nlp(' '.join(qj))
    words = []
    dp_linkage = {}

    for idx, token in enumerate(doc):

        words.append({"id": idx,
                      "text": token.text,
                      "dep": token.dep_,
                      "head": token.head.i})
                                                
                                                
    for i, j in itertools.product(range(len(words)), repeat=2):
        if i == j:
            continue

        elif words[i]['head'] == j:
            if i < j:
                dp_linkage[f"{i},{j}"] = 'F'
            elif i > j:
                dp_linkage[f"{i},{j}"] = 'B'

        elif words[j]['head'] == i:
            if j < i:
                dp_linkage[f"{j},{i}"] = 'F'
            elif j > i:
                dp_linkage[f"{j},{i}"] = 'B'

        dp_link = {"dp_link": dp_linkage}

    dp_whole_spacy.append(dp_link)

# %%
len(dp_whole)
# Out:
# 1

# %%
import stanza

nlp = stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma,depparse')
doc = nlp(question_join)

print(*[f'id: {word.id}\tword: {word.text}\thead id: {word.head}\thead: {sent.words[word.head-1].text if word.head > 0 else "root"}\tdeprel: {word.deprel}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# 2022-10-04 06:05:16 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2022-10-04 06:05:16 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# | depparse  | combined |
# ========================
#
# 2022-10-04 06:05:16 INFO: Use device: gpu
# 2022-10-04 06:05:16 INFO: Loading: tokenize
# 2022-10-04 06:05:17 INFO: Loading: pos
# 2022-10-04 06:05:17 INFO: Loading: lemma
# 2022-10-04 06:05:17 INFO: Loading: depparse
# 2022-10-04 06:05:18 INFO: Done loading processors!
# id: 1	word: how	head id: 2	head: many	deprel: advmod
# id: 2	word: many	head id: 7	head: es	deprel: amod
# id: 3	word: acting	head id: 4	head: status	deprel: compound
# id: 4	word: status	head id: 7	head: es	deprel: compound
# id: 5	word: #	head id: 7	head: es	deprel: compound
# id: 6	word: #	head id: 7	head: es	deprel: compound
# id: 7	word: es	head id: 9	head: there	deprel: nsubj
# id: 8	word: are	head id: 9	head: there	deprel: cop
# id: 9	word: there	head id: 0	head: root	deprel: root
# id: 10	word: ?	head id: 9	head: there	deprel: punct
